# %%
import onnx

model1 = onnx.load("w3-practicum-logistic.onnx")
model2 = onnx.load("w3-practicum-random-forest.onnx")

# %%
model1
# Out:
# ir_version: 3
# producer_name: "pytorch"
# producer_version: "0.3"
# graph {
#   node {
#     input: "gpa"
#     output: "3"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 1
#       ints: 0
#       type: INTS
#     }
# ...

# %%
model2
# Out:
# ir_version: 3
# producer_name: "OnnxMLTools"
# producer_version: "1.2.2.0129"
# domain: "onnxml"
# model_version: 0
# doc_string: ""
# graph {
#   node {
#     input: "input"
#     output: "label"
#     output: "probability_tensor"
#     name: "TreeEnsembleClassifier"
#     op_type: "TreeEnsembleClassifier"
#     attribute {
#       name: "class_ids"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
# ...
